# %%
# Dependencies and Setup
import pandas as pd
#import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
sdc_df = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
sdc_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#Count values
sdc_df.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# School ID        39170
# type             39170
# size             39170
# budget           39170
# dtype: int64

# %%
#Total Students using dataframe
total_students = sdc_df['Student ID'].count()
total_students
# Out:
# 39170

# %%
#Types of values
sdc_df.dtypes
# Out:
# Student ID        int64
# student_name     object
# gender           object
# grade            object
# school_name      object
# reading_score     int64
# math_score        int64
# School ID         int64
# type             object
# size              int64
# budget            int64
# dtype: object

# %%
#Total Schools using dataframe
total_schools = sdc_df['School ID'].nunique()
total_schools
# Out:
# 15

# %%
#Total Budget using school data to simplify
total_budget = school_data['budget'].sum()
total_budget = float(total_budget)
total_budget
# Out:
# 24649428.0

# %%
#Average Math using school data to simplify
average_math = (student_data['math_score'].sum()) / total_students
average_math
# Out:
# 78.98537145774827

# %%
#Average Math using school data to simplify
average_reading = (student_data['reading_score'].sum()) / total_students
average_reading
# Out:
# 81.87784018381414

# %%
# Math pass using school data to simplify, then get the value using only math colunm
Math_pass = student_data[student_data['math_score']>69].count()
math_pass = Math_pass['math_score']
math_pass
# Out:
# 29370

# %%
#Math percentage
math_percentage = (math_pass / total_students)*100
math_percentage
# Out:
# 74.9808526933878

# %%
# Reading pass using school data to simplify, then get the value using only math colunm
Reading_pass = student_data[student_data.reading_score>69].count()
reading_pass = Reading_pass['reading_score']
reading_pass
# Out:
# 33610

# %%
# Reading percentage
reading_percentage = (reading_pass / total_students)*100
reading_percentage
# Out:
# 85.80546336482001

# %%
# Overall pass using count and adding the column at the end to get the numeric value
Overall_pass = student_data[(student_data.reading_score>69) & (student_data.math_score>69)].count()['math_score']
Overall_pass
# Out:
# 25528

# %%
#Overall percentage
Overall_percentage = (Overall_pass / total_students) * 100
Overall_percentage
# Out:
# 65.17232575950983

# %%
#Use the variable obtained above to make a new data frame that summarize the district data. 

district_summary = {"Total Schools" : [total_schools],
                   "Total Students" : [total_students],
                   "Total Budget" : [total_budget],
                   "Average Math Score" : [average_math],
                   "Average Reading Score" : [average_reading],
                   "% Passing Math" : [math_percentage],
                   "% Passing Reading" : [reading_percentage],
                   "% Overall Passing" : [Overall_percentage]}
district_df = pd.DataFrame(district_summary)
district_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170    24649428.0           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
#Format the column for best reading.

# %%
#district_df["Total Students"] = (district_df["Total Students"]).map("{:,}".format)
#district_df['Total Students']

# %%
district_df["Total Students"] = district_df["Total Students"].map("{:,}".format)
district_df["Total Students"]
#district_df["Total Schools"] = district_df["Total Schools"].map("{:,.2}".format)
# Out:
# 0    39,170
# Name: Total Students, dtype: object

# %%
district_df["Total Budget"] = district_df["Total Budget"].map("${:,}".format)
district_df["Total Budget"]
# Out:
# 0    $24,649,428.0
# Name: Total Budget, dtype: object

# %%
#Mapping each colunm
 

#district_df["Total Budget"] = district_df["Total Budget"].map("${:,.2f}".format)
district_df["Average Math Score"] = district_df["Average Math Score"].map("{:,.2f}".format)
district_df["Average Reading Score"] = district_df["Average Reading Score"].map("{:,.2f}".format)
#district_df["% Passing Math"] = district_df["% Passing Math"].map("{:,.2f}%".format)
district_df["% Passing Reading"] = district_df["% Passing Reading"].map("{:,.2f}%".format)
district_df["% Overall Passing"] = district_df["% Overall Passing"].map("{:,.2f}%".format)

# %%
district_df["% Passing Math"] = district_df["% Passing Math"].map("{:,.2f}%".format)
district_df["% Passing Math"]
# Out:
# 0    74.98%
# Name: % Passing Math, dtype: object

# %% [markdown]
# # District Summary Complete

# %%
district_df
# Out:
#    Total Schools Total Students   Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428.0              78.99
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                 81.88         74.98%            85.81%            65.17%

# %%
district_df.to_clipboard(excel=True, sep=None)

# %% [markdown]
# # School Summary

# %%
indexed_df = pd.DataFrame(sdc_df.set_index(["school_name"]))
indexed_df
# Out:
#                     Student ID       student_name gender grade  reading_score  \
# school_name
# Huang High School            0       Paul Bradley      M   9th             66
# Huang High School            1       Victor Smith      M  12th             94
# Huang High School            2    Kevin Rodriguez      M  12th             90
# Huang High School            3  Dr. Richard Scott      M  12th             67
# Huang High School            4         Bonnie Ray      F   9th             97
# ...                        ...                ...    ...   ...            ...
# Thomas High School       39165       Donna Howard      F  12th             99
# Thomas High School       39166          Dawn Bell      F  10th             95
# Thomas High School       39167     Rebecca Tanner      F   9th             73
# Thomas High School       39168       Desiree Kidd      F  10th             99
# Thomas High School       39169    Carolyn Jackson      F  11th             95
#
# ...

# %%
school_types = sdc_df.groupby(["school_name"])["type"]
school_types

# %%
#School Types
school_summary = pd.DataFrame(sdc_df.set_index(["school_name"])["type"])
#school_types_df = pd.DataFrame(school_types)
school_summary # = school_summary['type'].rename('School type')
#school_summary
# Out:
#                         type
# school_name
# Huang High School   District
# Huang High School   District
# Huang High School   District
# Huang High School   District
# Huang High School   District
# ...                      ...
# Thomas High School   Charter
# Thomas High School   Charter
# Thomas High School   Charter
# Thomas High School   Charter
# Thomas High School   Charter
#
# [39170 rows x 1 columns]

# %%
per_school_budget = sdc_df.groupby(["school_name"]).mean()["budget"]
per_school_budget
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
# Calculate the total student count per school
per_school_counts = sdc_df["school_name"].value_counts()

# Calculate the total school budget and per capita spending

per_school_budget = sdc_df.groupby(["school_name"]).mean()["budget"]
per_school_capita = per_school_budget / per_school_counts


per_school_capita
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# Calculate the average test scores
per_school_math = sdc_df.groupby(["school_name"]).mean()["math_score"]
per_school_reading = sdc_df.groupby(["school_name"]).mean()["reading_score"]
per_school_math

sdc_df.groupby(["school_name"]).mean()["math_score"]
sdc_df.groupby(["school_name"]).mean()["reading_score"]
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# Get students who passed math per school
score_passing_math = sdc_df[sdc_df['math_score']>=70]
score_passing_math
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
# Get students who passed reading per school

#if the school name is = Huang High School then sum math score / school count
score_passing_reading = sdc_df[sdc_df['reading_score']>=70]
score_passing_reading
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 1                 94          61          0  District  2917  1910635
# ...

# %%
#passing both
score_passing_both = sdc_df[(sdc_df['math_score']>=70) & (sdc_df['reading_score']>=70)]
score_passing_both
# Out:
#        Student ID     student_name gender grade         school_name  \
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# 9               9   Matthew Greene      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 4                 97          84          0  District  2917  1910635
# ...

# %%
# Percentage math passing per school
#if the school name is = Huang High School then sum math score / school count
per_school_passing_math = score_passing_math.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100
per_school_passing_math
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
# Percentage math passing per school

per_school_passing_reading = score_passing_reading.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100
per_school_passing_reading
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
# Percentage math passing per school

per_school_passing_overall = score_passing_both.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100
per_school_passing_overall
# Out:
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# dtype: float64

# %%
school_summary["Total Students"] = sdc_df["school_name"].value_counts()
school_summary["Total School Budget"] = sdc_df.groupby(["school_name"]).mean()["budget"]
school_summary["Per Student Budget"] = (sdc_df.groupby(["school_name"]).mean()["budget"]) / sdc_df["school_name"].value_counts() 
school_summary["Average Math Score"] = sdc_df.groupby(["school_name"]).mean()["math_score"] 
school_summary["Average Reading Score"] = sdc_df.groupby(["school_name"]).mean()["reading_score"] 
school_summary["% Passing Math"] = score_passing_math.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100
school_summary["% Passing Reading"] = score_passing_reading.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100
school_summary["% Overall Passing"] = score_passing_both.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100
school_summary
# Out:
#                         type  Total Students  Total School Budget  \
# school_name
# Huang High School   District            2917            1910635.0
# Huang High School   District            2917            1910635.0
# Huang High School   District            2917            1910635.0
# Huang High School   District            2917            1910635.0
# Huang High School   District            2917            1910635.0
# ...                      ...             ...                  ...
# Thomas High School   Charter            1635            1043130.0
# Thomas High School   Charter            1635            1043130.0
# Thomas High School   Charter            1635            1043130.0
# Thomas High School   Charter            1635            1043130.0
# Thomas High School   Charter            1635            1043130.0
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Huang High School                655.0           76.629414
# ...

# %%
school_summary = school_summary.rename(columns={"type":"School Type"})
school_summary
# Out:
#                    School Type  Total Students  Total School Budget  \
# school_name
# Huang High School     District            2917            1910635.0
# Huang High School     District            2917            1910635.0
# Huang High School     District            2917            1910635.0
# Huang High School     District            2917            1910635.0
# Huang High School     District            2917            1910635.0
# ...                        ...             ...                  ...
# Thomas High School     Charter            1635            1043130.0
# Thomas High School     Charter            1635            1043130.0
# Thomas High School     Charter            1635            1043130.0
# Thomas High School     Charter            1635            1043130.0
# Thomas High School     Charter            1635            1043130.0
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Huang High School                655.0           76.629414
# ...

# %%
# Convert to DataFrame
per_school_summary = pd.DataFrame({#"School Type": school_types,
                                   "Total Students": sdc_df["school_name"].value_counts(),
                                   "Total School Budget": sdc_df.groupby(["school_name"]).mean()["budget"],
                                   "Per Student Budget": (sdc_df.groupby(["school_name"]).mean()["budget"]) / sdc_df["school_name"].value_counts(),
                                   "Average Math Score": sdc_df.groupby(["school_name"]).mean()["math_score"],
                                   "Average Reading Score": sdc_df.groupby(["school_name"]).mean()["reading_score"],
                                   "% Passing Math": score_passing_math.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100,
                                   "% Passing Reading": score_passing_reading.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100,
                                   "% Overall Passing": score_passing_both.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100 })
#per_school_summary_df = pd.DataFrame(per_school_summary)
per_school_summary
# Out:
#                        Total Students  Total School Budget  \
# Bailey High School               4976            3124928.0
# Cabrera High School              1858            1081356.0
# Figueroa High School             2949            1884411.0
# Ford High School                 2739            1763916.0
# Griffin High School              1468             917500.0
# Hernandez High School            4635            3022020.0
# Holden High School                427             248087.0
# Huang High School                2917            1910635.0
# Johnson High School              4761            3094650.0
# Pena High School                  962             585858.0
# Rodriguez High School            3999            2547363.0
# Shelton High School              1761            1056600.0
# Thomas High School               1635            1043130.0
# Wilson High School               2283            1319574.0
# Wright High School               1800            1049400.0
#
# ...

# %%
#per_school_summary["School Type"] = sdc_df.set_index(["school_name"])["type"]
#per_school_summary

# %%
#Mapping and formatting

per_school_summary["Total Students"] = per_school_summary["Total Students"].map("{:,}".format)
per_school_summary["Total School Budget"] = per_school_summary["Total School Budget"].map("${:,}".format)
per_school_summary["Per Student Budget"] = per_school_summary["Per Student Budget"].map("${:,}".format)
per_school_summary["Average Math Score"] = per_school_summary["Average Math Score"].map("{:,.2f}".format)
per_school_summary["Average Reading Score"] = per_school_summary["Average Reading Score"].map("{:,.2f}".format)
per_school_summary["% Passing Math"] = per_school_summary["% Passing Math"].map("{:,.2f}%".format)
per_school_summary["% Passing Reading"] = per_school_summary["% Passing Reading"].map("{:,.2f}%".format)
per_school_summary["% Overall Passing"] = per_school_summary["% Overall Passing"].map("{:,.2f}%".format)

per_school_summary
# Out:
#                       Total Students Total School Budget Per Student Budget  \
# Bailey High School             4,976        $3,124,928.0             $628.0
# Cabrera High School            1,858        $1,081,356.0             $582.0
# Figueroa High School           2,949        $1,884,411.0             $639.0
# Ford High School               2,739        $1,763,916.0             $644.0
# Griffin High School            1,468          $917,500.0             $625.0
# Hernandez High School          4,635        $3,022,020.0             $652.0
# Holden High School               427          $248,087.0             $581.0
# Huang High School              2,917        $1,910,635.0             $655.0
# Johnson High School            4,761        $3,094,650.0             $650.0
# Pena High School                 962          $585,858.0             $609.0
# Rodriguez High School          3,999        $2,547,363.0             $637.0
# ...

# %%
#Mapping and formatting


school_summary["Total Students"] = school_summary["Total Students"].map("{:,}".format)
school_summary["Total School Budget"] = school_summary["Total School Budget"].map("${:,}".format)
school_summary["Per Student Budget"] = school_summary["Per Student Budget"].map("${:,}".format)
school_summary["Average Math Score"] = school_summary["Average Math Score"].map("{:,.2f}".format)
school_summary["Average Reading Score"] = school_summary["Average Reading Score"].map("{:,.2f}".format)
school_summary["% Passing Math"] = school_summary["% Passing Math"].map("{:,.2f}%".format)
school_summary["% Passing Reading"] = school_summary["% Passing Reading"].map("{:,.2f}%".format)
school_summary["% Overall Passing"] = school_summary["% Overall Passing"].map("{:,.2f}%".format)

school_summary
# Out:
#                    School Type Total Students Total School Budget  \
# school_name
# Huang High School     District          2,917        $1,910,635.0
# Huang High School     District          2,917        $1,910,635.0
# Huang High School     District          2,917        $1,910,635.0
# Huang High School     District          2,917        $1,910,635.0
# Huang High School     District          2,917        $1,910,635.0
# ...                        ...            ...                 ...
# Thomas High School     Charter          1,635        $1,043,130.0
# Thomas High School     Charter          1,635        $1,043,130.0
# Thomas High School     Charter          1,635        $1,043,130.0
# Thomas High School     Charter          1,635        $1,043,130.0
# Thomas High School     Charter          1,635        $1,043,130.0
#
#                    Per Student Budget Average Math Score  \
# school_name
# Huang High School              $655.0              76.63
# ...

# %%
school_summary.to_clipboard(excel=True, sep=None)

# %% [markdown]
# # Sort Schools by performing

# %%
# Sort and display the top five schools in overall passing rate
top_performing_schools = per_school_summary.sort_values(by='% Overall Passing',ascending=False)
top_performing_schools.head()
# Out:
#                     Total Students Total School Budget Per Student Budget  \
# Cabrera High School          1,858        $1,081,356.0             $582.0
# Thomas High School           1,635        $1,043,130.0             $638.0
# Griffin High School          1,468          $917,500.0             $625.0
# Wilson High School           2,283        $1,319,574.0             $578.0
# Pena High School               962          $585,858.0             $609.0
#
#                     Average Math Score Average Reading Score % Passing Math  \
# Cabrera High School              83.06                 83.98         94.13%
# Thomas High School               83.42                 83.85         93.27%
# Griffin High School              83.35                 83.82         93.39%
# Wilson High School               83.27                 83.99         93.87%
# Pena High School                 83.84                 84.04         94.59%
#
#                     % Passing Reading % Overall Passing
# ...

# %%
worst_performing_schools = per_school_summary.sort_values(by='% Overall Passing')
worst_performing_schools.head()
# Out:
#                       Total Students Total School Budget Per Student Budget  \
# Rodriguez High School          3,999        $2,547,363.0             $637.0
# Figueroa High School           2,949        $1,884,411.0             $639.0
# Huang High School              2,917        $1,910,635.0             $655.0
# Hernandez High School          4,635        $3,022,020.0             $652.0
# Johnson High School            4,761        $3,094,650.0             $650.0
#
#                       Average Math Score Average Reading Score % Passing Math  \
# Rodriguez High School              76.84                 80.74         66.37%
# Figueroa High School               76.71                 81.16         65.99%
# Huang High School                  76.63                 81.18         65.68%
# Hernandez High School              77.29                 80.93         66.75%
# Johnson High School                77.07                 80.97         66.06%
#
# ...

# %% [markdown]
# # Math score by grade

# %%
# Calculate the average math score for students of 9th grade at each school
avg_math_9th = sdc_df[sdc_df['grade']=='9th'].groupby('school_name')['math_score'].mean()
# Calculate the average math score for students of 10th grade at each school
avg_math_10th = sdc_df[sdc_df['grade']=='10th'].groupby('school_name')['math_score'].mean()
# Calculate the average math score for students of 11th grade at each school
avg_math_11th = sdc_df[sdc_df['grade']=='11th'].groupby('school_name')['math_score'].mean()
# Calculate the average math score for students of 12th grade at each school
avg_math_12th = sdc_df[sdc_df['grade']=='12th'].groupby('school_name')['math_score'].mean()

# Create a dataframe to hold the above results
grade_math_score={
    '9th': avg_math_9th,
    '10th': avg_math_10th,
    '11th': avg_math_11th,
    '12th': avg_math_12th,
    }

math_score_by_grade = pd.DataFrame(grade_math_score)
math_score_by_grade.index.name = None
math_score_by_grade.head(20)
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# # Reading score by grade

# %%
# Calculate the average reading score for students of 9th grade at each school
school_avg_reading_9th = sdc_df[sdc_df['grade']=='9th'].groupby('school_name')['reading_score'].mean()
# Calculate the average reading score for students of 10th grade at each school
school_avg_reading_10th = sdc_df[sdc_df['grade']=='10th'].groupby('school_name')['reading_score'].mean()
# Calculate the average reading score for students of 11th grade at each school
school_avg_reading_11th = sdc_df[sdc_df['grade']=='11th'].groupby('school_name')['reading_score'].mean()
# Calculate the average reading score for students of 12th grade at each school
school_avg_reading_12th = sdc_df[sdc_df['grade']=='12th'].groupby('school_name')['reading_score'].mean()

# Create a dataframe to hold the above results
grade_reading_score={
    '9th':school_avg_reading_9th,
    '10th':school_avg_reading_10th,
    '11th':school_avg_reading_11th,
    '12th':school_avg_reading_12th,
    }

reading_score_by_grade = pd.DataFrame(grade_reading_score)
reading_score_by_grade.index.name = None
reading_score_by_grade.head(20)
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# # Score by School Spending

# %%
#binning per budget
spending_bins = [0,585,630,645,680]
spendign_ranges = ['0-$585','$585-630', '$630-645', '$645-680']

# %%
# Create a new data frame by locating the desired columns
scores_spending = per_school_summary.loc["% Passing Math",
                                  "% Passing Reading"]
                                  
# Add a new columns named Spending Ranges (Per Student) and binning based off budget per student
#scores_spending['Spending Ranges (Per Student)']= pd.cut(school_summary['Per Student Budget'],spending_bins,labels=group_names)
# Create a group based off of the bins
#scores_spending = scores_spending.groupby('Spending Ranges (Per Student)').mean()
#scores_spending.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '% Passing Math'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-c3b045e6439f> in <module>
# ...

# %%
#binning per budget
spending_bins = [0,585,630,645,680]
spendign_ranges = ['0-$585','$585-630', '$630-645', '$645-680']

# %%
# Create a new data frame by locating the desired columns
scores_spending = per_school_summary.loc[:,['Average Math Score',
                                  'Average Reading Score','% Passing Math',
                                  '% Passing Reading','% Overall Passing Rate',]]
# Add a new columns named Spending Ranges (Per Student) and binning based off budget per student
scores_spending['Spending Ranges (Per Student)']= pd.cut(school_summary['Per Student Budget'],spending_bins,labels=group_names)
# Create a group based off of the bins
scores_spending = scores_spending.groupby('Spending Ranges (Per Student)').mean()
scores_spending.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-ea725429274f> in <module>
#       1 # Create a new data frame by locating the desired columns
# ----> 2 scores_spending = per_school_summary.loc[:,['Average Math Score',
#       3                                   'Average Reading Score','% Passing Math',
#       4                                   '% Passing Reading','% Overall Passing Rate',]]
#       5 # Add a new columns named Spending Ranges (Per Student) and binning based off budget per student
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ...

# %%
per_budget_math = pd.cut(per_school_summary["Total School Budget"], spending_bins, labels=spendign_ranges)

per_budget_math
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-eeea7271c672> in <module>
# ----> 1 per_budget_math = pd.cut(per_school_summary["Total School Budget"], spending_bins, labels=spendign_ranges)
#       2
#       3 per_budget_math
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     255             raise ValueError("bins must increase monotonically.")
#     256
# --> 257     fac, bins = _bins_to_cuts(
#     258         x,
#     259         bins,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     386
#     387     side = "left" if right else "right"
# --> 388     ids = ensure_int64(bins.searchsorted(x, side=side))
#     389
#     390     if include_lowest:
#
# ...

# %%
# Create a copy of the school summary since it has the "Per Student Budget" 
#  This step can be skip but its best to make a copy. 
school_spending_df = per_school_summary

# Categorize spending based on the bins.
school_spending_df["Spending Ranges (Per Student)"] = pd.cut(per_school_capita, spending_bins, labels=spendign_ranges, right=False)
school_spending_df
# Out:
#                       Total Students Total School Budget Per Student Budget  \
# Bailey High School             4,976        $3,124,928.0             $628.0
# Cabrera High School            1,858        $1,081,356.0             $582.0
# Figueroa High School           2,949        $1,884,411.0             $639.0
# Ford High School               2,739        $1,763,916.0             $644.0
# Griffin High School            1,468          $917,500.0             $625.0
# Hernandez High School          4,635        $3,022,020.0             $652.0
# Holden High School               427          $248,087.0             $581.0
# Huang High School              2,917        $1,910,635.0             $655.0
# Johnson High School            4,761        $3,094,650.0             $650.0
# Pena High School                 962          $585,858.0             $609.0
# Rodriguez High School          3,999        $2,547,363.0             $637.0
# ...

# %% [markdown]
# # Scores by School Size

# %%
# Sample bins
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
# Create a new data frame by locating the desired columns
scores_size = school_summary.loc[:,['Average Math Score',
                                  'Average Reading Score','% Passing Math',
                                  '% Passing Reading','% Overall Passing Rate',]]
# Add a new columns named School Size and binning based off total students
scores_size['School Size']= pd.cut(school_summary['Total Students'],size_bins,labels=group_names)
# Create a group based off of the bins
scores_size = scores_size.groupby('School Size').mean()
scores_size.head()

# %% [markdown]
# ## Scores by School Type

# %%
# Create a new data frame with our desired columns
#scores_type = school_summary[['School Type','Average Math Score',
#                                  'Average Reading Score','% Passing Math',
#                                  '% Passing Reading','% Overall Passing Rate',]]
# Create a group based off of the school type
#scores_type = scores_type.groupby('School Type').mean()
#scores_type.head()
